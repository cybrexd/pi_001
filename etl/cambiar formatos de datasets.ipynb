# %%
import pandas as pd

# %%
#se formatean los archivos para la carga ingremental a la DB en el formato correcto

# %%
df1 = pd.read_json("Datasets relevamiento precios/precios_semana_20200503.json")
df1.to_csv("Datasets relevamiento precios/precios_semana_20200503.csv",index=False)

# %%
df2 = pd.read_excel("Datasets relevamiento precios/precios_semanas_20200419_20200426.xlsx", sheet_name = 'precios_20200419_20200419')
df3 = pd.read_excel("Datasets relevamiento precios/precios_semanas_20200419_20200426.xlsx", sheet_name = 'precios_20200426_20200426')

df2.to_csv("Datasets relevamiento precios/precios_semana_20200419.csv",index=False)
df3.to_csv("Datasets relevamiento precios/precios_semana_20200426.csv",index=False)

# %%
df4 = pd.read_parquet("Datasets relevamiento precios/producto.parquet")

df4 = df4.drop(["categoria1","categoria2",'categoria3',"presentacion"],axis=1)

df4.to_csv("Datasets relevamiento precios/producto.csv",index=False)

# %%
df4 = df4.drop_duplicates(subset="id")
df4
# Out:
#                       id               marca  \
# 0          0000000001663          LA ANÓNIMA
# 2          0000000205870           SIN MARCA
# 24         0000000221184            PALADINI
# 25         0000000230407          LA PAULINA
# 26         0000000231688              DULCOR
# ...                  ...                 ...
# 70944  9-1-0000000999137  LA HACIEDA BANDEJA
# 71193  9-2-0000000895316             NEXCARE
# 72027      9044400841000                 PEZ
# 72030      9312631127591              DILMAH
# 72035      9990385651922                DANA
#
#                                                   nombre
# 0                        Radicheta Atada La Anonima 1 Un
# 2                                       Ojo de Bife 1 Kg
# 24                      Salchichon Feteado Paladini 1 Kg
# 25                  Queso Senda en Sobre La Paulina 1 Kg
# 26                          Dulce de Zapallo Dulcor 1 Kg
# ...                                                  ...
# ...

# %%
df5 = pd.read_csv("Datasets relevamiento precios/precios_semana_20200518.csv",delimiter="|")

df5.to_csv("precio_semana_20200518.csv")

df5
# Out:
#         precio    producto_id sucursal_id
# 0        29.90  0000000002288     2-1-009
# 1        32.90  0000000002288     2-1-037
# 2        36.90  0000000002288     2-1-090
# 3        39.90  0000000002288     2-3-247
# 4       499.99  0000000205870     9-1-430
# ...        ...            ...         ...
# 415288  149.99  9569753142128      25-1-1
# 415289   34.99  9795403001143      25-1-1
# 415290  312.50  9990385651922       5-1-4
# 415291  312.50  9990385651939       5-1-4
# 415292  198.90  9990385651946       5-1-4
#
# [415293 rows x 3 columns]

# %%
df6 = pd.read_csv(r"Datasets relevamiento precios\precios_semana_20200413.csv",encoding="utf-16")
df6.to_csv("precios_semana_20200413.csv")
